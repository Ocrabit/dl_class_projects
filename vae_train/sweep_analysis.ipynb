# %%
import wandb
from wandb.apis.public import Api
import pandas as pd
import json
from tqdm import tqdm

# %%
sweep = Api().sweep("marcocassar-belmont-university/dl_experimentation-vae_train/sweeps/mho772yy")

# %%
run_info = []
run_history = []

for run in tqdm(sweep.runs, desc="Processing runs", leave=False):
    run_info.append({
        **{k: v.get("value") for k, v in json.loads(run.config).items() if k != "_wandb"},
        "name": run.name,
        "id": run.id
    })

    historical_list = []
    for row in run.scan_history():
        if row.get('val_mae') is not None:
            historical_list.append(row)

    run_history.append(historical_list)

# %%
from itertools import chain

df = pd.DataFrame(chain.from_iterable(
    ({**info, **h} for h in hist) for info, hist in zip(run_info, run_history)
))

# %%
names = [
    'glowing-sweep-110',
    'earthy-sweep-151',
    'dainty-sweep-158',
    'stoic-sweep-74',
    'silver-sweep-152',
    'young-sweep-114'
]

df_filtered = df[(df['name'].isin(names)) & (df['epoch'] == 25)]

# %%
df_filtered[['id', 'name', 'ema', 'epochs', 'groups', 'use_bn', 'dropout', 'use_skips',
       'activation', 'batch_size', 'beta_final', 'latent_dim', 'model_class',
       'total_params', 'weight_decay', 'base_channels', 'learning_rate',
       'warmup_epochs', 'blocks_per_level']].to_json('filtered.json', orient='records', indent=2)

# %%
df.to_csv("sweep_validation_data.csv", index=False)

# %%
history_ = run1.history()

# %%
history_[history_['val_mae'].notna()]
# Out:
#     train_loss_ema    val_mae reconstructions  step  kl_loss  val_kl_loss  \
# 39             NaN  55.555211            None   NaN      NaN     2.207841
# 58             NaN  52.275953            None   NaN      NaN     2.093837
#
#     val_loss    val_mse   val_psnr    _timestamp  ...  val_recon_loss  epoch  \
# 39  1.270278  20.834136  15.761083  1.760152e+09  ...        0.141800    2.0
# 58  1.745504  20.475784  15.837057  1.760152e+09  ...        0.140191    3.0
#
#     _step   mu_mean    mu_std  beta*kl  beta  val_correlation  recon_loss  \
# 39    471  0.058157  1.130187      NaN   NaN         0.843620         NaN
# 58    707 -0.007232  1.128706      NaN   NaN         0.850897         NaN
#
#     train_loss
# 39         NaN
# 58         NaN
#
# [2 rows x 21 columns]

# %%
for row in run1.scan_history():
    row1 = row
    break

# %%
historical_list = []
for row in run1.scan_history():
    if row['val_mae'] is not None:
        historical_list.append(row)

# %%
test_df = pd.DataFrame(historical_list)

# %%
test_df[test_df['val_mae'].notna()]
# Out:
#       train_loss_ema    val_mae reconstructions  step  kl_loss  val_kl_loss  \
# 235              NaN  70.066091            None   NaN      NaN     2.267438
# 471              NaN  55.555211            None   NaN      NaN     2.207841
# 707              NaN  52.275953            None   NaN      NaN     2.093837
# 943              NaN  49.912699            None   NaN      NaN     1.974694
# 1179             NaN  48.780382            None   NaN      NaN     1.836701
# 1416             NaN  49.398270            None   NaN      NaN     1.735265
# 1652             NaN  48.778059            None   NaN      NaN     1.714474
# 1888             NaN  49.082003            None   NaN      NaN     1.649483
# 2124             NaN  49.578079            None   NaN      NaN     1.579041
# 2360             NaN  51.105715            None   NaN      NaN     1.477711
# 2597             NaN  50.352834            None   NaN      NaN     1.486848
# ...

# %%
artifacts = []
for art in run1.logged_artifacts():
    artifacts.append(art)

# %%
def callable_attrs(obj, include_dunder=False):
    names = []
    for name in dir(obj):
        if not include_dunder and name.startswith("__"):
            continue
        val = getattr(obj, name, None)   # <- default avoids crashing
        if callable(val):
            names.append(name)
    return names

callable_attrs(run1)  # returns only methods you can actually call
# Out:
# wandb: WARNING Run.username is deprecated. Please use Run.entity instead.
# ['_exec',
#  '_full_history',
#  '_load_from_attrs',
#  '_load_with_fragment',
#  '_repr_html_',
#  '_sampled_history',
#  'create',
#  'delete',
#  'display',
#  'file',
#  'files',
#  'history',
#  'load',
#  'load_full_data',
#  'log_artifact',
#  'logged_artifacts',
#  'save',
#  'scan_history',
#  'snake_to_camel',
#  'to_html',
#  'update',
#  'upload_file',
#  'use_artifact',
#  'used_artifacts',
#  'wait_until_finished']
